# %% [markdown]
# <a href="https://colab.research.google.com/github/sujit-deokar/SVHN_Dataset/blob/main/RESNET_CBAM_SVHN_Usecase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
os.chdir("/content/gdrive/My Drive/SVHN_Dataset") # path to change

# %%
from __future__ import print_function
import keras
import tensorflow as tf
from keras.layers import Dense, Conv2D, BatchNormalization, Activation, Concatenate, Add, Lambda,AveragePooling2D
from keras.layers import GlobalAveragePooling2D, GlobalMaxPooling2D, Reshape, multiply, Permute, Input, Flatten
from keras.activations import sigmoid
#from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
#from models import resnext, resnet_v1, resnet_v2, mobilenets, inception_v3, inception_resnet_v2, densenet
#from utils import lr_schedule
import numpy as np
import os
import keras
import seaborn as sns
from matplotlib import pyplot as plt
from scipy.io import loadmat
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import confusion_matrix
from keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
# %matplotlib inline
from keras.utils.vis_utils import plot_model

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 40:
        lr *= 0.5e-3
    elif epoch > 30:
        lr *= 1e-3
    elif epoch > 20:
        lr *= 1e-2
    elif epoch > 10:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %%
def resnet_layer(inputs,num_filters=16,kernel_size=3,strides=1,activation='relu',batch_normalization=True,conv_first=True):

    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x


def cbam_block(cbam_feature, ratio=8):
	"""Contains the implementation of Convolutional Block Attention Module(CBAM) block.
	As described in https://arxiv.org/abs/1807.06521.
	"""
	
	cbam_feature = channel_attention(cbam_feature, ratio)
	cbam_feature = spatial_attention(cbam_feature)
	return cbam_feature

def channel_attention(input_feature, ratio=8):
	
	channel_axis = 1 if K.image_data_format() == "channels_first" else -1
	channel = input_feature.shape[channel_axis]
	
	shared_layer_one = Dense(channel//ratio,
							 activation='relu',
							 kernel_initializer='he_normal',
							 use_bias=True,
							 bias_initializer='zeros')
	shared_layer_two = Dense(channel,
							 kernel_initializer='he_normal',
							 use_bias=True,
							 bias_initializer='zeros')
	
	avg_pool = GlobalAveragePooling2D()(input_feature)    
	avg_pool = Reshape((1,1,channel))(avg_pool)
	assert avg_pool.shape[1:] == (1,1,channel)
	avg_pool = shared_layer_one(avg_pool)
	assert avg_pool.shape[1:] == (1,1,channel//ratio)
	avg_pool = shared_layer_two(avg_pool)
	assert avg_pool.shape[1:] == (1,1,channel)
	
	max_pool = GlobalMaxPooling2D()(input_feature)
	max_pool = Reshape((1,1,channel))(max_pool)
	assert max_pool.shape[1:] == (1,1,channel)
	max_pool = shared_layer_one(max_pool)
	assert max_pool.shape[1:] == (1,1,channel//ratio)
	max_pool = shared_layer_two(max_pool)
	assert max_pool.shape[1:] == (1,1,channel)
	
	cbam_feature = Add()([avg_pool,max_pool])
	cbam_feature = Activation('sigmoid')(cbam_feature)
	
	if K.image_data_format() == "channels_first":
		cbam_feature = Permute((3, 1, 2))(cbam_feature)
	
	return multiply([input_feature, cbam_feature])

def spatial_attention(input_feature):
	kernel_size = 7
	
	if K.image_data_format() == "channels_first":
		channel = input_feature.shape[1]
		cbam_feature = Permute((2,3,1))(input_feature)
	else:
		channel = input_feature.shape[-1]
		cbam_feature = input_feature
	
	avg_pool = Lambda(lambda x: K.mean(x, axis=3, keepdims=True))(cbam_feature)
	assert avg_pool.shape[-1] == 1
	max_pool = Lambda(lambda x: K.max(x, axis=3, keepdims=True))(cbam_feature)
	assert max_pool.shape[-1] == 1
	concat = Concatenate(axis=3)([avg_pool, max_pool])
	assert concat.shape[-1] == 2
	cbam_feature = Conv2D(filters = 1,
					kernel_size=kernel_size,
					strides=1,
					padding='same',
					activation='sigmoid',
					kernel_initializer='he_normal',
					use_bias=False)(concat)	
	assert cbam_feature.shape[-1] == 1
	
	if K.image_data_format() == "channels_first":
		cbam_feature = Permute((3, 1, 2))(cbam_feature)
		
	return multiply([input_feature, cbam_feature])

# %%
# Load the data
train_raw = loadmat('train_32x32.mat')
test_raw = loadmat('test_32x32.mat')
# Load images and labels

train_images = np.array(train_raw['X'])
test_images = np.array(test_raw['X'])

train_labels = train_raw['y']
test_labels = test_raw['y']
# Check the shape of the data

print(train_images.shape)
print(test_images.shape)
# Fix the axes of the images

train_images = np.moveaxis(train_images, -1, 0)
test_images = np.moveaxis(test_images, -1, 0)

print(train_images.shape)
print(test_images.shape)

# Convert train and test images into 'float64' type

train_images = train_images.astype('float64')
test_images = test_images.astype('float64')

# Convert train and test labels into 'int64' type

train_labels = train_labels.astype('int64')
test_labels = test_labels.astype('int64')

# Normalize the images data

print('Min: {}, Max: {}'.format(train_images.min(), train_images.max()))

train_images /= 255.0
test_images /= 255.0

# One-hot encoding of train and test labels

lb = LabelBinarizer()
train_labels = lb.fit_transform(train_labels)
test_labels = lb.fit_transform(test_labels)
# Out:
# (32, 32, 3, 73257)
# (32, 32, 3, 26032)
# (73257, 32, 32, 3)
# (26032, 32, 32, 3)
# Min: 0.0, Max: 255.0

# %%
X_train, X_val, y_train, y_val = train_test_split(train_images, train_labels,test_size=0.15, random_state=22)
datagen = ImageDataGenerator(rotation_range=8,
                             zoom_range=[0.95, 1.05],
                             height_shift_range=0.10,
                             shear_range=0.15)

# %%
num_filters = 16
num_res_blocks = 1
inputs = Input(shape=(32, 32, 3))
x = resnet_layer(inputs=inputs)
# Instantiate the stack of residual units
for stack in range(3):
    for res_block in range(num_res_blocks):
        strides = 1
        if stack > 0 and res_block == 0:  # first layer but not first stack
            strides = 2  # downsample
        y = resnet_layer(inputs=x,
                         num_filters=num_filters,
                         strides=strides)
        y = resnet_layer(inputs=y,
                         num_filters=num_filters,
                         activation=None)
        if stack > 0 and res_block == 0:  # first layer but not first stack
            # linear projection residual shortcut connection to match
            # changed dims
            x = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             kernel_size=1,
                             strides=strides,
                             activation=None,
                             batch_normalization=False)
        # attention_module
        y = cbam_block(y)
        x = keras.layers.add([x, y])
        x = Activation('relu')(x)
    num_filters *= 2

# Add classifier on top.
# v1 does not use BN after last shortcut connection-ReLU
x = AveragePooling2D(pool_size=8)(x)
y = Flatten()(x)
outputs = Dense(10,
                activation='softmax',
                kernel_initializer='he_normal')(y)

# Instantiate model.
model = Model(inputs=inputs, outputs=outputs)

model.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(lr=lr_schedule(0)),
              metrics=['accuracy'])
model.summary()
# Out:
# Learning rate:  0.001
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 16)   448         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 16)   64          conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 32, 32, 16)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 32, 32, 16)   2320        activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 32, 32, 16)   64          conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 32, 32, 16)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 32, 32, 16)   2320        activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 32, 32, 16)   64          conv2d_14[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 16)           0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_3 (GlobalM (None, 16)           0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# reshape_6 (Reshape)             (None, 1, 1, 16)     0           global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# reshape_7 (Reshape)             (None, 1, 1, 16)     0           global_max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1, 1, 2)      34          reshape_6[0][0]
#                                                                  reshape_7[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 1, 1, 16)     48          dense_7[0][0]
#                                                                  dense_7[1][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 1, 1, 16)     0           dense_8[0][0]
#                                                                  dense_8[1][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 1, 1, 16)     0           add_6[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 32, 32, 16)   0           batch_normalization_9[0][0]
#                                                                  activation_12[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 32, 32, 1)    0           multiply_6[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 32, 32, 1)    0           multiply_6[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 32, 32, 2)    0           lambda_6[0][0]
#                                                                  lambda_7[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 32, 32, 1)    98          concatenate_3[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 32, 32, 16)   0           multiply_6[0][0]
#                                                                  conv2d_15[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 32, 32, 16)   0           activation_10[0][0]
#                                                                  multiply_7[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 32, 32, 16)   0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 16, 16, 32)   4640        activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16, 16, 32)   128         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 16, 16, 32)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 16, 16, 32)   9248        activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16, 16, 32)   128         conv2d_17[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 32)           0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_4 (GlobalM (None, 32)           0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# reshape_8 (Reshape)             (None, 1, 1, 32)     0           global_average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# reshape_9 (Reshape)             (None, 1, 1, 32)     0           global_max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 1, 1, 4)      132         reshape_8[0][0]
#                                                                  reshape_9[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 1, 1, 32)     160         dense_9[0][0]
#                                                                  dense_9[1][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 1, 1, 32)     0           dense_10[0][0]
#                                                                  dense_10[1][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 1, 1, 32)     0           add_8[0][0]
# __________________________________________________________________________________________________
# multiply_8 (Multiply)           (None, 16, 16, 32)   0           batch_normalization_11[0][0]
#                                                                  activation_15[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 16, 16, 1)    0           multiply_8[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 16, 16, 1)    0           multiply_8[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 16, 16, 2)    0           lambda_8[0][0]
#                                                                  lambda_9[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 16, 16, 1)    98          concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 16, 16, 32)   544         activation_13[0][0]
# __________________________________________________________________________________________________
# multiply_9 (Multiply)           (None, 16, 16, 32)   0           multiply_8[0][0]
#                                                                  conv2d_19[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 16, 16, 32)   0           conv2d_18[0][0]
#                                                                  multiply_9[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 16, 16, 32)   0           add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 8, 8, 64)     18496       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 8, 8, 64)     256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 8, 8, 64)     0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 8, 8, 64)     36928       activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 8, 8, 64)     256         conv2d_21[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_5 (Glo (None, 64)           0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_5 (GlobalM (None, 64)           0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# reshape_10 (Reshape)            (None, 1, 1, 64)     0           global_average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# reshape_11 (Reshape)            (None, 1, 1, 64)     0           global_max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 1, 1, 8)      520         reshape_10[0][0]
#                                                                  reshape_11[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 1, 1, 64)     576         dense_11[0][0]
#                                                                  dense_11[1][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 1, 1, 64)     0           dense_12[0][0]
#                                                                  dense_12[1][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 1, 1, 64)     0           add_10[0][0]
# __________________________________________________________________________________________________
# multiply_10 (Multiply)          (None, 8, 8, 64)     0           batch_normalization_13[0][0]
#                                                                  activation_18[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 8, 8, 1)      0           multiply_10[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 8, 8, 1)      0           multiply_10[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 8, 8, 2)      0           lambda_10[0][0]
#                                                                  lambda_11[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 8, 8, 1)      98          concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 8, 8, 64)     2112        activation_16[0][0]
# __________________________________________________________________________________________________
# multiply_11 (Multiply)          (None, 8, 8, 64)     0           multiply_10[0][0]
#                                                                  conv2d_23[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 8, 8, 64)     0           conv2d_22[0][0]
#                                                                  multiply_11[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 8, 8, 64)     0           add_11[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 1, 1, 64)     0           activation_19[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 64)           0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 10)           650         flatten_1[0][0]
# ==================================================================================================
# Total params: 80,430
# Trainable params: 79,950
# Non-trainable params: 480
# __________________________________________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
model_type = 'Resnet_cbam'
print(model_type)

# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'SVHN_%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_accuracy',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)
lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]
X_train, X_val, y_train, y_val
history = model.fit_generator(datagen.flow(X_train, y_train, batch_size=128),
                        validation_data=(X_val, y_val),
                        epochs=35, verbose=1, workers=4,
                        callbacks=callbacks)
# Out:
# Resnet_cbam
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/35
# Learning rate:  0.001
# 487/487 [==============================] - 75s 146ms/step - loss: 1.6708 - accuracy: 0.4617 - val_loss: 1.1249 - val_accuracy: 0.6600
#
# Epoch 00001: val_accuracy improved from -inf to 0.66002, saving model to /content/gdrive/My Drive/SVHN_Dataset/saved_models/SVHN_Resnet_cbam_model.001.h5
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/35
# Learning rate:  0.001
# 487/487 [==============================] - 68s 139ms/step - loss: 0.7009 - accuracy: 0.8136 - val_loss: 0.5812 - val_accuracy: 0.8491
#
# Epoch 00002: val_accuracy improved from 0.66002 to 0.84912, saving model to /content/gdrive/My Drive/SVHN_Dataset/saved_models/SVHN_Resnet_cbam_model.002.h5
# Epoch 3/35
# Learning rate:  0.001
# 487/487 [==============================] - 68s 139ms/step - loss: 0.4971 - accuracy: 0.8713 - val_loss: 0.4668 - val_accuracy: 0.8771
#
# Epoch 00003: val_accuracy improved from 0.84912 to 0.87706, saving model to /content/gdrive/My Drive/SVHN_Dataset/saved_models/SVHN_Resnet_cbam_model.003.h5
# Epoch 4/35
# Learning rate:  0.001
# 487/487 [==============================] - 68s 140ms/step - loss: 0.4260 - accuracy: 0.8931 - val_loss: 0.4238 - val_accuracy: 0.8939
#
# Epoch 00004: val_accuracy improved from 0.87706 to 0.89389, saving model to /content/gdrive/My Drive/SVHN_Dataset/saved_models/SVHN_Resnet_cbam_model.004.h5
# Epoch 5/35
# Learning rate:  0.001
# 487/487 [==============================] - 69s 141ms/step - loss: 0.3879 - accuracy: 0.9033 - val_loss: 0.4175 - val_accuracy: 0.8933
#
# Epoch 00005: val_accuracy did not improve from 0.89389
# Epoch 6/35
# Learning rate:  0.001
# 487/487 [==============================] - 69s 141ms/step - loss: 0.3651 - accuracy: 0.9109 - val_loss: 0.3887 - val_accuracy: 0.9080
#
# Epoch 00006: val_accuracy improved from 0.89389 to 0.90800, saving model to /content/gdrive/My Drive/SVHN_Dataset/saved_models/SVHN_Resnet_cbam_model.006.h5
# Epoch 7/35
# Learning rate:  0.001
# 487/487 [==============================] - 68s 139ms/step - loss: 0.3467 - accuracy: 0.9158 - val_loss: 0.3799 - val_accuracy: 0.9067
#
# Epoch 00007: val_accuracy did not improve from 0.90800
# Epoch 8/35
# Learning rate:  0.001
# 487/487 [==============================] - 67s 138ms/step - loss: 0.3320 - accuracy: 0.9201 - val_loss: 0.3468 - val_accuracy: 0.9166
#
# Epoch 00008: val_accuracy improved from 0.90800 to 0.91655, saving model to /content/gdrive/My Drive/SVHN_Dataset/saved_models/SVHN_Resnet_cbam_model.008.h5
# Epoch 9/35
# Learning rate:  0.001
# 487/487 [==============================] - 69s 141ms/step - loss: 0.3221 - accuracy: 0.9250 - val_loss: 0.3545 - val_accuracy: 0.9149
#
# Epoch 00009: val_accuracy did not improve from 0.91655
# Epoch 10/35
# Learning rate:  0.001
# 487/487 [==============================] - 68s 140ms/step - loss: 0.3141 - accuracy: 0.9259 - val_loss: 0.4405 - val_accuracy: 0.8880
#
# Epoch 00010: val_accuracy did not improve from 0.91655
# Epoch 11/35
# Learning rate:  0.001
# 487/487 [==============================] - 68s 140ms/step - loss: 0.3020 - accuracy: 0.9296 - val_loss: 0.3307 - val_accuracy: 0.9222
#
# Epoch 00011: val_accuracy improved from 0.91655 to 0.92219, saving model to /content/gdrive/My Drive/SVHN_Dataset/saved_models/SVHN_Resnet_cbam_model.011.h5
# Epoch 12/35
# Learning rate:  0.0001
# 487/487 [==============================] - 68s 138ms/step - loss: 0.2621 - accuracy: 0.9429 - val_loss: 0.2824 - val_accuracy: 0.9387
#
# Epoch 00012: val_accuracy improved from 0.92219 to 0.93867, saving model to /content/gdrive/My Drive/SVHN_Dataset/saved_models/SVHN_Resnet_cbam_model.012.h5
# Epoch 13/35
# Learning rate:  0.0001
# 487/487 [==============================] - 68s 140ms/step - loss: 0.2519 - accuracy: 0.9457 - val_loss: 0.2810 - val_accuracy: 0.9390
#
# Epoch 00013: val_accuracy improved from 0.93867 to 0.93903, saving model to /content/gdrive/My Drive/SVHN_Dataset/saved_models/SVHN_Resnet_cbam_model.013.h5
# Epoch 14/35
# Learning rate:  0.0001
# 487/487 [==============================] - 68s 139ms/step - loss: 0.2427 - accuracy: 0.9494 - val_loss: 0.2806 - val_accuracy: 0.9394
#
# Epoch 00014: val_accuracy improved from 0.93903 to 0.93939, saving model to /content/gdrive/My Drive/SVHN_Dataset/saved_models/SVHN_Resnet_cbam_model.014.h5
# Epoch 15/35
# Learning rate:  0.0001
# 487/487 [==============================] - 68s 139ms/step - loss: 0.2402 - accuracy: 0.9496 - val_loss: 0.2845 - val_accuracy: 0.9378
#
# Epoch 00015: val_accuracy did not improve from 0.93939
# Epoch 16/35
# Learning rate:  0.0001
# 487/487 [==============================] - 68s 140ms/step - loss: 0.2391 - accuracy: 0.9498 - val_loss: 0.2812 - val_accuracy: 0.9379
#
# Epoch 00016: val_accuracy did not improve from 0.93939
# Epoch 17/35
# Learning rate:  0.0001
# 487/487 [==============================] - 69s 141ms/step - loss: 0.2354 - accuracy: 0.9506 - val_loss: 0.2798 - val_accuracy: 0.9379
#
# Epoch 00017: val_accuracy did not improve from 0.93939
# Epoch 18/35
# Learning rate:  0.0001
# 487/487 [==============================] - 69s 140ms/step - loss: 0.2324 - accuracy: 0.9510 - val_loss: 0.2786 - val_accuracy: 0.9393
#
# Epoch 00018: val_accuracy did not improve from 0.93939
# Epoch 19/35
# Learning rate:  0.0001
# 487/487 [==============================] - 68s 139ms/step - loss: 0.2290 - accuracy: 0.9527 - val_loss: 0.2825 - val_accuracy: 0.9388
#
# Epoch 00019: val_accuracy did not improve from 0.93939
# Epoch 20/35
# Learning rate:  0.0001
# 487/487 [==============================] - 69s 140ms/step - loss: 0.2268 - accuracy: 0.9532 - val_loss: 0.2781 - val_accuracy: 0.9379
#
# Epoch 00020: val_accuracy did not improve from 0.93939
# Epoch 21/35
# Learning rate:  0.0001
# 487/487 [==============================] - 69s 140ms/step - loss: 0.2241 - accuracy: 0.9546 - val_loss: 0.2784 - val_accuracy: 0.9381
#
# Epoch 00021: val_accuracy did not improve from 0.93939
# Epoch 22/35
# Learning rate:  1e-05
# 487/487 [==============================] - 68s 139ms/step - loss: 0.2179 - accuracy: 0.9555 - val_loss: 0.2744 - val_accuracy: 0.9402
#
# Epoch 00022: val_accuracy improved from 0.93939 to 0.94021, saving model to /content/gdrive/My Drive/SVHN_Dataset/saved_models/SVHN_Resnet_cbam_model.022.h5
# Epoch 23/35
# Learning rate:  1e-05
# 487/487 [==============================] - 69s 141ms/step - loss: 0.2182 - accuracy: 0.9561 - val_loss: 0.2742 - val_accuracy: 0.9400
#
# Epoch 00023: val_accuracy did not improve from 0.94021
# Epoch 24/35
# Learning rate:  1e-05
# 487/487 [==============================] - 68s 139ms/step - loss: 0.2178 - accuracy: 0.9557 - val_loss: 0.2744 - val_accuracy: 0.9402
#
# Epoch 00024: val_accuracy did not improve from 0.94021
# Epoch 25/35
# Learning rate:  1e-05
# 487/487 [==============================] - 69s 140ms/step - loss: 0.2171 - accuracy: 0.9565 - val_loss: 0.2743 - val_accuracy: 0.9400
#
# Epoch 00025: val_accuracy did not improve from 0.94021
# Epoch 26/35
# Learning rate:  1e-05
# 487/487 [==============================] - 69s 142ms/step - loss: 0.2157 - accuracy: 0.9568 - val_loss: 0.2742 - val_accuracy: 0.9399
#
# Epoch 00026: val_accuracy did not improve from 0.94021
# Epoch 27/35
# Learning rate:  1e-05
# 487/487 [==============================] - 69s 140ms/step - loss: 0.2165 - accuracy: 0.9568 - val_loss: 0.2745 - val_accuracy: 0.9398
#
# Epoch 00027: val_accuracy did not improve from 0.94021
# Epoch 28/35
# Learning rate:  1e-05
# 487/487 [==============================] - 69s 141ms/step - loss: 0.2139 - accuracy: 0.9576 - val_loss: 0.2746 - val_accuracy: 0.9401
#
# Epoch 00028: val_accuracy did not improve from 0.94021
# Epoch 29/35
# Learning rate:  1e-05
# 487/487 [==============================] - 68s 139ms/step - loss: 0.2155 - accuracy: 0.9567 - val_loss: 0.2744 - val_accuracy: 0.9405
#
# Epoch 00029: val_accuracy improved from 0.94021 to 0.94049, saving model to /content/gdrive/My Drive/SVHN_Dataset/saved_models/SVHN_Resnet_cbam_model.029.h5
# Epoch 30/35
# Learning rate:  1e-05
# 487/487 [==============================] - 69s 140ms/step - loss: 0.2154 - accuracy: 0.9566 - val_loss: 0.2742 - val_accuracy: 0.9404
#
# Epoch 00030: val_accuracy did not improve from 0.94049
# Epoch 31/35
# Learning rate:  1e-05
# 487/487 [==============================] - 70s 143ms/step - loss: 0.2157 - accuracy: 0.9567 - val_loss: 0.2740 - val_accuracy: 0.9397
#
# Epoch 00031: val_accuracy did not improve from 0.94049
# Epoch 32/35
# Learning rate:  1e-06
# 487/487 [==============================] - 69s 141ms/step - loss: 0.2174 - accuracy: 0.9559 - val_loss: 0.2741 - val_accuracy: 0.9398
#
# Epoch 00032: val_accuracy did not improve from 0.94049
# Epoch 33/35
# Learning rate:  1e-06
# 487/487 [==============================] - 69s 140ms/step - loss: 0.2144 - accuracy: 0.9571 - val_loss: 0.2740 - val_accuracy: 0.9398
#
# Epoch 00033: val_accuracy did not improve from 0.94049
# Epoch 34/35
# Learning rate:  1e-06
# 487/487 [==============================] - 69s 141ms/step - loss: 0.2129 - accuracy: 0.9582 - val_loss: 0.2739 - val_accuracy: 0.9398
#
# Epoch 00034: val_accuracy did not improve from 0.94049
# Epoch 35/35
# Learning rate:  1e-06
# 487/487 [==============================] - 69s 142ms/step - loss: 0.2159 - accuracy: 0.9565 - val_loss: 0.2739 - val_accuracy: 0.9398
#
# Epoch 00035: val_accuracy did not improve from 0.94049
